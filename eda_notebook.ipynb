# %% [markdown]
# # India Air Quality EDA (2019 – 2023)
# Run `src/eda_analysis.py` to generate all figures, or work through this notebook interactively.
# See README.md for full project documentation.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('../data/india_air_quality_2019_2023.csv')
df.head()
